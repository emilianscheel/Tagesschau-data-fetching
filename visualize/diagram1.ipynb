# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

news = pd.read_json('../data/database.json')

# %%
import seaborn as sns  
from matplotlib.dates import DateFormatter

df = (pd.to_datetime(news['date'])
       .dt.floor('d')
       .value_counts()
       .rename_axis('date')
       .reset_index(name='count'))

df['count'].mean()
# Out:
# 35.357142857142854

# %%
import seaborn as sns  
from matplotlib.dates import DateFormatter
from sklearn.linear_model import Ridge

df = (pd.to_datetime(news['date'])
       .dt.floor('d')
       .value_counts()
       .rename_axis('date')
       .reset_index(name='count')
       .sort_values('date'))

df.plot.bar(x='date', y='count', figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
news['category'].value_counts().plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
news.loc[(news["ressort"] == 'inland')].shape[0]
# Out:
# 482
