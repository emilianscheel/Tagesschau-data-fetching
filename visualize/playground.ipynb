# %%
import seaborn as sns
import pandas as pd

flights = pd.read_csv('flights.csv')
flightsPivot = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flightsPivot, linewidths=.5, annot=True, fmt="d", cmap="YlGnBu")

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline

Cols= ['0-2 h', '3-5', '6-8 h', '9-11 h', '12-14 h', '15-17 h', '18-20 h', '21-23 h']
Index = ['Montag', 'Dienstag', 'Mittwoch', 'Donnerstag', 'Freitag']
df = DataFrame(abs(np.random.randn(5, 8)), index=Index, columns=Cols)

sns.heatmap(df, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Import data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

news = pd.read_json('../data/database.json')

# %%
import calendar
import datetime

# Erstellt eine neue Zeile mit dem Wochentag
news['day_of_week'] = news['date'].dt.day_of_week
news['day_of_week_word'] = news['date'].dt.day_name(locale='de_de') 

news['hour'] = news['date'].dt.hour

# %%
news = news.groupby(["hour", "day_of_week"]).size().reset_index(name="amount")

# %%
from importlib.resources import path
import seaborn as sns
import pandas as pd

sns.set(rc={'figure.figsize':(20,5)})

newsPivot = news.pivot("day_of_week", "hour", "amount")
ax = sns.heatmap(newsPivot, linewidths=.5, annot=True, fmt="d", cmap="YlGnBu")

newsPivot.to_json('news.json')

# %%
print(len(news.index))
# Out:
# 168

# %%
f = news['day_of_week'].value_counts().plot(kind='heatmap', figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/coderdojo/Developer/PythonProjects/Tagesschau/visualize/playground.ipynb Zelle 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/coderdojo/Developer/PythonProjects/Tagesschau/visualize/playground.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> f = news['day_of_week'].value_counts().plot(kind='heatmap', figsize=(20,10))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/plotting/_core.py:905, in PlotAccessor.__call__(self, *args, **kwargs)
#     902     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     904 if kind not in self._all_kinds:
# --> 905     raise ValueError(f"{kind} is not a valid plot kind")
#     907 # The original data structured can be transformed before passed to the
# ...

# %%
# Gruppiert die Zeit 
d = news.groupby(['day_of_week']).size()

print(d)
# Out:
# day_of_week
# 0    302
# 1    339
# 2    304
# 3    338
# 4    298
# 5    198
# 6    201
# dtype: int64

# %%
print(type(news))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
news.head()
# Out:
#                            sophoraId  \
# 0         entlassungen-selenskyj-101
# 1  russland-protest-owsjannikowa-101
# 2        liveblog-ukraine-montag-151
# 3      ukraine-waffenlieferungen-107
# 4  afd-chrupalla-sommerinterview-103
#
#                                           title  \
# 0         Selenskyj feuert zentrale Mitarbeiter
# 1            Owsjannikowa vorübergehend in Haft
# 2     ++ Selenskyj erneuert Kritik an Kanada ++
# 3  Der blinde Fleck der ukrainischen Flugabwehr
# 4              "Es geht um deutsche Interessen"
#
#                                              content  \
# 0  Der ukrainische Präsident Wolodymyr Selenskyj ...
# 1  Nach einer zweiten Protestaktion gegen Russlan...
# 2  Der ukrainische Präsident Selenskyj verlangt v...
# 3  Während die ukrainische Flugabwehr auf russisc...
# 4  Die Bundesregierung sollte bei ihrer Reaktion ...
#
#                               date         firstDownload  \
# 0 2022-07-18 00:02:49.860000+02:00  18-07-2022--03-00-00
# ...

# %%
final = news.sort_values(by='day', ascending=False)
final[0:200]['author'].value_counts().plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
news.loc[(news["ressort"] == 'inland')].shape[0]
# Out:
# 482
