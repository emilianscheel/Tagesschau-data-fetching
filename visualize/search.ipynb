# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import networkx as nx

df = pd.read_json('../data/database-27-10.json')

# %%
df.describe()
# Out:
# /var/folders/bc/qptbbs8s5qb7xdt31yl10bnm0000gn/T/ipykernel_13739/3627053830.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#                          sophoraId  \
# count                         4852
# unique                        4852
# top     entlassungen-selenskyj-101
# freq                             1
# first                          NaN
# last                           NaN
#
#                                                  title content  \
# count                                             4852    4852
# unique                                            4794    4717
# top     "Das Boot"-Regisseur Wolfgang Petersen ist tot
# freq                                                 3     125
# first                                              NaN     NaN
# ...

# %%
df.head()
# Out:
#                            sophoraId  \
# 0         entlassungen-selenskyj-101
# 1  russland-protest-owsjannikowa-101
# 2        liveblog-ukraine-montag-151
# 3      ukraine-waffenlieferungen-107
# 4  afd-chrupalla-sommerinterview-103
#
#                                           title  \
# 0         Selenskyj feuert zentrale Mitarbeiter
# 1            Owsjannikowa vorübergehend in Haft
# 2     ++ Selenskyj erneuert Kritik an Kanada ++
# 3  Der blinde Fleck der ukrainischen Flugabwehr
# 4              "Es geht um deutsche Interessen"
#
#                                              content  \
# 0  Der ukrainische Präsident Wolodymyr Selenskyj ...
# 1  Nach einer zweiten Protestaktion gegen Russlan...
# 2  Der ukrainische Präsident Selenskyj verlangt v...
# 3  Während die ukrainische Flugabwehr auf russisc...
# 4  Die Bundesregierung sollte bei ihrer Reaktion ...
#
#                               date         firstDownload  \
# 0 2022-07-18 00:02:49.860000+02:00  18-07-2022--03-00-00
# ...

# %%
search = "WDR"


df[df['sender'].str.contains("ARD")].size
# Out:
# 13035
